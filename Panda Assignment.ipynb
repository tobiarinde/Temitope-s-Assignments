# %% [markdown]
# ## PANDA ASSIGNMENT

# %%
## Question 1

# %%
import pandas as pd

# %%
flight = r"C:\Users\MY PC\Desktop\Python Class\flights-2.csv"

gap = pd.read_csv(flight)

gap
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0          1    1        4      WN     LAX      SLC       1625       58.0
# 1          1    1        4      UA     DEN      IAD        823        7.0
# 2          1    1        4      MQ     DFW      VPS       1305       36.0
# 3          1    1        4      AA     DFW      DCA       1555        7.0
# 4          1    1        4      WN     LAX      MCI       1720       48.0
# ...      ...  ...      ...     ...     ...      ...        ...        ...
# 58487     12   31        4      AA     SFO      DFW        515        5.0
# 58488     12   31        4      F9     LAS      SFO       1910       13.0
# 58489     12   31        4      OO     SFO      SBA       1846       -6.0
# 58490     12   31        4      WN     MSP      ATL        525       39.0
# 58491     12   31        4      OO     SFO      BOI        859        5.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# ...

# %%
# Finding the number of canceled flights for every airline per weekday

gap3 = gap.groupby(["AIRLINE", "WEEKDAY"])["CANCELLED"].sum()
gap3
# Out:
# AIRLINE  WEEKDAY
# AA       1          41
#          2           9
#          3          16
#          4          20
#          5          18
#                     ..
# WN       3          18
#          4          10
#          5           7
#          6          10
#          7           7
# Name: CANCELLED, Length: 98, dtype: int64

# %%
# Finding the number and percentage of canceled and diverted flights for every airline per weekday

gap2 = gap.groupby(["AIRLINE", "WEEKDAY"])[["DIVERTED", "CANCELLED"]].sum()*0.01
gap2
# Out:
#                  DIVERTED  CANCELLED
# AIRLINE WEEKDAY
# AA      1            0.06       0.41
#         2            0.02       0.09
#         3            0.02       0.16
#         4            0.05       0.20
#         5            0.01       0.18
# ...                   ...        ...
# WN      3            0.02       0.18
#         4            0.04       0.10
#         5            0.00       0.07
#         6            0.03       0.10
#         7            0.03       0.07
#
# [98 rows x 2 columns]

# %%
# For each origin and destination, finding the total number of flights, the number and percentage of canceled flights, and the average and variance of the airtime

gap3 = gap.groupby(["ORG_AIR", "DEST_AIR"])["AIRLINE"].count()
gap3
# Out:
# ORG_AIR  DEST_AIR
# ATL      ABE          31
#          ABQ          16
#          ABY          19
#          ACY           6
#          AEX          40
#                     ...
# SFO      SNA         122
#          STL          20
#          SUN          10
#          TUS          20
#          XNA           2
# Name: AIRLINE, Length: 1130, dtype: int64

# %%
# Question 2

# %%
import numpy as np

# %%
covid = pd.read_csv(r"C:\Users\MY PC\Desktop\Python Class\covid_subset-1.txt")

covid
# Out:
#     iso_code continent     location        date  total_cases  new_cases  \
# 0        AFG      Asia  Afghanistan  2019-12-31          0.0        0.0
# 1        AFG      Asia  Afghanistan  2020-01-01          0.0        0.0
# 2        AFG      Asia  Afghanistan  2020-01-02          0.0        0.0
# 3        AFG      Asia  Afghanistan  2020-01-03          0.0        0.0
# 4        AFG      Asia  Afghanistan  2020-01-04          0.0        0.0
# ..       ...       ...          ...         ...          ...        ...
# 200      AFG      Asia  Afghanistan  2020-07-28      36368.0      105.0
# 201      AFG      Asia  Afghanistan  2020-07-29      36471.0      103.0
# 202      AFG      Asia  Afghanistan  2020-07-30      36471.0        0.0
# 203      AFG      Asia  Afghanistan  2020-07-31      36542.0       71.0
# 204      AFG      Asia  Afghanistan  2020-08-01      36710.0      168.0
#
#      total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
covid.shape
# Out:
# (205, 36)

# %%
covid1 = covid[["continent", "location", "total_cases", "total_deaths", "gdp_per_capita", "tests_per_case", "life_expectancy","female_smokers", "male_smokers", "diabetes_prevalence"]]

# %%
covid1
# Out:
#     continent     location  total_cases  total_deaths  gdp_per_capita  \
# 0        Asia  Afghanistan          0.0           0.0        1803.987
# 1        Asia  Afghanistan          0.0           0.0        1803.987
# 2        Asia  Afghanistan          0.0           0.0        1803.987
# 3        Asia  Afghanistan          0.0           0.0        1803.987
# 4        Asia  Afghanistan          0.0           0.0        1803.987
# ..        ...          ...          ...           ...             ...
# 200      Asia  Afghanistan      36368.0        1270.0        1803.987
# 201      Asia  Afghanistan      36471.0        1271.0        1803.987
# 202      Asia  Afghanistan      36471.0        1271.0        1803.987
# 203      Asia  Afghanistan      36542.0        1271.0        1803.987
# 204      Asia  Afghanistan      36710.0        1283.0        1803.987
#
#      tests_per_case  life_expectancy  female_smokers  male_smokers  \
# ...

# %%
covid1.isnull().sum()
# Out:
# continent                0
# location                 0
# total_cases              0
# total_deaths             0
# gdp_per_capita           0
# tests_per_case         205
# life_expectancy          0
# female_smokers         205
# male_smokers           205
# diabetes_prevalence      0
# dtype: int64

# %%
covid2 = covid1.groupby(["continent"])[["total_cases", "total_deaths"]].max()

# %%
covid2
# Out:
#            total_cases  total_deaths
# continent
# Asia           36710.0        1283.0

# %%
covid3 = covid1.groupby(["location"])["total_deaths"].max()

# %%
covid3
# Out:
# location
# Afghanistan    1283.0
# Name: total_deaths, dtype: float64

# %%
covid4 = covid1.groupby(["continent"])[["total_cases", "total_deaths"]].max()

# %%
covid4
# Out:
#            total_cases  total_deaths
# continent
# Asia           36710.0        1283.0
